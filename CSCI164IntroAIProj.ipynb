# %% [markdown]
# <a href="https://colab.research.google.com/github/Dexless/CSCI-164-Colab-Repo/blob/main/CSCI164IntroAIProj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSCI 164 Project

# %%
# !pip install -U transformers accelerate bitsandbytes
import warnings
from transformers import pipeline
from transformers.utils import logging
warnings.filterwarnings(action= 'ignore')
logging.set_verbosity(40)

# %%
# Add !gdown here
# !gdown 1sN5iPAXd_7A2aiVopDEyZAQ9qZb6INKi
j_pic = "/content/Scenery-4.jpg"

# !gdown 1oa_yPZcvRl_Pe5ID9X9w2UUNtL-xw37z
tj_pic = "/content/Black_Porsche.jpg"

#!gdown 1sN5iPAXd_7A2aiVopDEyZAQ9qZb6INKi
#l_pic = "/content/Dog_on_Bed.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1sN5iPAXd_7A2aiVopDEyZAQ9qZb6INKi
# To: /content/Scenery-4.jpg
# 100% 1.72M/1.72M [00:00<00:00, 30.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oa_yPZcvRl_Pe5ID9X9w2UUNtL-xw37z
# To: /content/Black_Porsche.jpg
# 100% 3.93M/3.93M [00:00<00:00, 34.4MB/s]

# %% [markdown]
# # Jason Avalos - 3 Model Image Processing / Image: Scenery-4.jpg / Image Description: The image depicts a non-operational red windmill located in Solvang, CA.
# ---
# Note: Model Loading Problem: Due to recent changes to HuggingFace and the transformer package, none of the modules will load as of 02/03/26

# %%
### Task: Image captioning
j_captioner1 = pipeline("image-text-to-text", model="HuggingFaceTB/SmolVLM-256M-Instruct")
#j_captioner2 = pipeline("image-text-to-text", model="Salesforce/blip-image-captioning-base")
#j_captioner3 = pipeline("image-text-to-text", model="microsoft/git-base")
# Out:
# Loading weights:   0%|          | 0/471 [00:00<?, ?it/s]

# %%
j_captioner1(images=j_pic)
#j_captioner2(j_pic)
#j_captioner3(j_pic)
# Out:
# [{'input_text': '/content/Scenery-4.jpg',
# ...

# %% [markdown]
# # Theodore Williams Jr. - 3 Model Image Processing / Image: Black_Porsche.jpg / Image Description: The image contains a black Porsche racecar inside a museum.
# ---
# Model Loading Problem: Due to recent changes to HuggingFace and the transformer package, none of the modules will load as of 02/03/26

# %%
### Task: Image captioning
#tj_captioner1 = pipeline("image-text-to-text", model="nlpconnect/vit-gpt2-image-captioning")
#tj_captioner2 = pipeline("image-text-to-text", model="Salesforce/blip-image-captioning-base")
#tj_captioner3 = pipeline("image-text-to-text", model="microsoft/git-base")

# %%
#tj_captioner1(tj_pic)
#tj_captioner2(tj_pic)
#tj_captioner3(tj_pic)

# %% [markdown]
# # Lizeth Campos - 3 Model Image Processing / Image: Dog_on_Bed.jpg / Image Description: The image contains a small black-and-white dog lying on a bed surrounded by blankets and pillows.
# ---
# Model Loading Problem: Due to recent changes to HuggingFace and the transformer package, none of the modules will load as of 02/03/26

# %%
### Task: Image captioning
#l_captioner1 = pipeline("image-text-to-text", model="nlpconnect/vit-gpt2-image-captioning")
#l_captioner2 = pipeline("image-text-to-text", model="Salesforce/blip-image-captioning-base")
#l_captioner3 = pipeline("image-text-to-text", model="microsoft/git-base")

# %%
#l_captioner1(l_pic)
#l_captioner2(l_pic)
#l_captioner3(l_pic)
